# %% [markdown]
# **Import Python Packages:**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os # to use operating system dependent functionality
import librosa # to extract speech features
import wave # read and write WAV files
import matplotlib.pyplot as plt # to generate the visualizations

# MLP Classifier
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# LSTM Classifier
import keras
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import *
from keras.optimizers import rmsprop
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-88f53c96b045> in <module>
#       2 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#       3 import os # to use operating system dependent functionality
# ----> 4 import librosa # to extract speech features
#       5 import wave # read and write WAV files
#       6 import matplotlib.pyplot as plt # to generate the visualizations
#
# ~\Anaconda3\lib\site-packages\librosa\__init__.py in <module>
#      10 # And all the librosa sub-modules
#      11 from . import cache
# ---> 12 from . import core
#      13 from . import beat
#      14 from . import decompose
#
# ~\Anaconda3\lib\site-packages\librosa\core\__init__.py in <module>
#     108
#     109 from .time_frequency import *  # pylint: disable=wildcard-import
# --> 110 from .audio import *  # pylint: disable=wildcard-import
#     111 from .spectrum import *  # pylint: disable=wildcard-import
#     112 from .pitch import *  # pylint: disable=wildcard-import
#
# ~\Anaconda3\lib\site-packages\librosa\core\audio.py in <module>
#      10 import scipy.signal
#      11 import scipy.fftpack as fft
# ---> 12 import resampy
#      13
#      14 from .time_frequency import frames_to_samples, time_to_samples
#
# ~\Anaconda3\lib\site-packages\resampy\__init__.py in <module>
#       5 from .version import version as __version__
#       6 from . import filters
# ----> 7 from .core import *
#
# ~\Anaconda3\lib\site-packages\resampy\core.py in <module>
#       7 from .filters import get_filter
#       8
# ----> 9 from .interpn import resample_f
#      10
#      11 __all__ = ['resample']
#
# ~\Anaconda3\lib\site-packages\resampy\interpn.py in <module>
#       5
#       6
# ----> 7 @numba.jit(nopython=True, nogil=True)
#       8 def resample_f(x, y, sample_ratio, interp_win, interp_delta, num_table):
#       9
#
# ~\Anaconda3\lib\site-packages\numba\decorators.py in wrapper(func)
#     172         disp = dispatcher(py_func=func, locals=locals,
#     173                           targetoptions=targetoptions,
# --> 174                           **dispatcher_args)
#     175         if cache:
#     176             disp.enable_caching()
#
# ~\Anaconda3\lib\site-packages\numba\dispatcher.py in __init__(self, py_func, locals, targetoptions, impl_kind, pipeline_class)
#     539         """
#     540         self.typingctx = self.targetdescr.typing_context
# --> 541         self.targetctx = self.targetdescr.target_context
#     542
#     543         pysig = utils.pysignature(py_func)
#
# ~\Anaconda3\lib\site-packages\numba\targets\registry.py in target_context(self)
#      48             return nested
#      49         else:
# ---> 50             return self._toplevel_target_context
#      51
#      52     @property
#
# ~\Anaconda3\lib\site-packages\numba\utils.py in __get__(self, instance, type)
#     355         if instance is None:
#     356             return self
# --> 357         res = instance.__dict__[self.name] = self.func(instance)
#     358         return res
#     359
#
# ~\Anaconda3\lib\site-packages\numba\targets\registry.py in _toplevel_target_context(self)
#      32     def _toplevel_target_context(self):
#      33         # Lazily-initialized top-level target context, for all threads
# ---> 34         return cpu.CPUContext(self.typing_context)
#      35
#      36     @utils.cached_property
#
# ~\Anaconda3\lib\site-packages\numba\targets\base.py in __init__(self, typing_context)
#     248
#     249         # Initialize
# --> 250         self.init()
#     251
#     252     def init(self):
#
# ~\Anaconda3\lib\site-packages\numba\compiler_lock.py in _acquire_compile_lock(*args, **kwargs)
#      30         def _acquire_compile_lock(*args, **kwargs):
#      31             with self:
# ---> 32                 return func(*args, **kwargs)
#      33         return _acquire_compile_lock
#      34
#
# ~\Anaconda3\lib\site-packages\numba\targets\cpu.py in init(self)
#      45     def init(self):
#      46         self.is32bit = (utils.MACHINE_BITS == 32)
# ---> 47         self._internal_codegen = codegen.JITCPUCodegen("numba.exec")
#      48
#      49         # Add ARM ABI functions from libgcc_s
#
# ~\Anaconda3\lib\site-packages\numba\targets\codegen.py in __init__(self, module_name)
#     606         self._llvm_module.name = "global_codegen_module"
#     607         self._rtlinker = RuntimeLinker()
# --> 608         self._init(self._llvm_module)
#     609
#     610     def _init(self, llvm_module):
#
# ~\Anaconda3\lib\site-packages\numba\targets\codegen.py in _init(self, llvm_module)
#     615         self._tm_features = self._customize_tm_features()
#     616         self._customize_tm_options(tm_options)
# --> 617         tm = target.create_target_machine(**tm_options)
#     618         engine = ll.create_mcjit_compiler(llvm_module, tm)
#     619
#
# TypeError: create_target_machine() got an unexpected keyword argument 'jitdebug'

# %%
def extract_mfcc(wav_file_name):
    #This function extracts mfcc features and obtain the mean of each dimension
    #Input : path_to_wav_file
    #Output: mfcc_features'''
    y, sr = librosa.load(wav_file_name)
    mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T,axis=0)
    
    return mfccs

# %%
##### load radvess speech data #####
radvess_speech_labels = [] # to save extracted label/file
ravdess_speech_data = [] # to save extracted features/file
for dirname, _, filenames in os.walk('C:\\Users\\HP\\Downloads\\107620_256618_bundle_archive\\'):
    for filename in filenames:
        #print(os.path.join(dirname, filename))
        radvess_speech_labels.append(int(filename[7:8]) - 1) # the index 7 and 8 of the file name represent the emotion label
        wav_file_name = os.path.join(dirname, filename)
        ravdess_speech_data.append(extract_mfcc(wav_file_name)) # extract MFCC features/file
        
print("Finish Loading the Dataset")
# Out:
# Finish Loading the Dataset

# %% [markdown]
# **Preparing the dataset for machine learning models:**

# %%
#### convert data and label to array
ravdess_speech_data_array = np.asarray(ravdess_speech_data) # convert the input to an array
ravdess_speech_label_array = np.array(radvess_speech_labels)
ravdess_speech_label_array.shape # get tuple of array dimensions

#### make categorical labels
labels_categorical = to_categorical(ravdess_speech_label_array) # converts a class vector (integers) to binary class matrix
ravdess_speech_data_array.shape
labels_categorical.shape
# Out:
# (2880, 8)

# %%
x_train,x_test,y_train,y_test= train_test_split(np.array(ravdess_speech_data_array),labels_categorical, test_size=0.20, random_state=9)

# %%
# Initialize the Multi Layer Perceptron Classifier
model=MLPClassifier(alpha=0.01, batch_size=256, epsilon=1e-08, hidden_layer_sizes=(300,), learning_rate='adaptive', max_iter=500)

# %%
# Train the model
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %% [markdown]
# *  **Generates output predictions for the input samples.**

# %%
# Predict for the test set
y_pred=model.predict(x_test)

# %%
# Calculate the accuracy of our model
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)
# Print the accuracy
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 41.49%

# %%
# Split the training, validating, and testing sets
number_of_samples = ravdess_speech_data_array.shape[0]
training_samples = int(number_of_samples * 0.8)
validation_samples = int(number_of_samples * 0.1)
test_samples = int(number_of_samples * 0.1)

# %%
# Define the LSTM model
def create_model_LSTM():
    model = Sequential()
    model.add(LSTM(128, return_sequences=False, input_shape=(40, 1)))
    model.add(Dense(64))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(32))
    model.add(Dropout(0.4))
    model.add(Activation('relu'))
    model.add(Dense(8))
    model.add(Activation('softmax'))
    
    # Configures the model for training
    model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
    return model

# %%
### train using LSTM model
model_A = create_model_LSTM()
history = model_A.fit(np.expand_dims(ravdess_speech_data_array[:training_samples],-1), labels_categorical[:training_samples], validation_data=(np.expand_dims(ravdess_speech_data_array[training_samples:training_samples+validation_samples], -1), labels_categorical[training_samples:training_samples+validation_samples]), epochs=100, shuffle=True)
# Out:
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\HP\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 2304 samples, validate on 288 samples
# Epoch 1/100
# 2304/2304 [==============================] - 6s 3ms/step - loss: 2.0656 - acc: 0.1576 - val_loss: 2.0319 - val_acc: 0.2292
# Epoch 2/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 2.0207 - acc: 0.1853 - val_loss: 1.9808 - val_acc: 0.2639
# Epoch 3/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.9844 - acc: 0.2166 - val_loss: 1.9350 - val_acc: 0.2396
# Epoch 4/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.9222 - acc: 0.2478 - val_loss: 1.8539 - val_acc: 0.2951
# Epoch 5/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.8844 - acc: 0.2826 - val_loss: 1.8452 - val_acc: 0.2847
# Epoch 6/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.8501 - acc: 0.2773 - val_loss: 1.8188 - val_acc: 0.3194
# Epoch 7/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.8436 - acc: 0.2917 - val_loss: 1.8105 - val_acc: 0.3056
# Epoch 8/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.8177 - acc: 0.2964 - val_loss: 1.7999 - val_acc: 0.3021
# Epoch 9/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.7795 - acc: 0.3181 - val_loss: 1.7760 - val_acc: 0.3368
# Epoch 10/100
# 2304/2304 [==============================] - 2s 1ms/step - loss: 1.7879 - acc: 0.3021 - val_loss: 1.7382 - val_acc: 0.3438
# Epoch 11/100
# 2304/2304 [==============================] - 2s 1ms/step - loss: 1.7518 - acc: 0.3220 - val_loss: 1.7377 - val_acc: 0.3229
# Epoch 12/100
# 2304/2304 [==============================] - 2s 1ms/step - loss: 1.7523 - acc: 0.3299 - val_loss: 1.7285 - val_acc: 0.3264
# Epoch 13/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.7254 - acc: 0.3333 - val_loss: 1.7055 - val_acc: 0.3194
# Epoch 14/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.7014 - acc: 0.3381 - val_loss: 1.7193 - val_acc: 0.3472
# Epoch 15/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.6793 - acc: 0.3533 - val_loss: 1.6615 - val_acc: 0.3472
# Epoch 16/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.6654 - acc: 0.3589 - val_loss: 1.7473 - val_acc: 0.3333
# Epoch 17/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1.6765 - acc: 0.3559 - val_loss: 1.6106 - val_acc: 0.4062
# Epoch 18/100
# 2304/2304 [==============================] - 4s 2ms/step - loss: 1.6290 - acc: 0.3681 - val_loss: 1.6272 - val_acc: 0.3924
# Epoch 19/100
# 2304/2304 [==============================] - 4s 2ms/step - loss: 1.6071 - acc: 0.3707 - val_loss: 1.6398 - val_acc: 0.3715
# Epoch 20/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 1
100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.4016 - acc: 0.8624 - val_loss: 0.4533 - val_acc: 0.8368
# Epoch 80/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.4099 - acc: 0.8728 - val_loss: 0.4397 - val_acc: 0.8646
# Epoch 81/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.4352 - acc: 0.8624 - val_loss: 0.6496 - val_acc: 0.7639
# Epoch 82/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.4696 - acc: 0.8533 - val_loss: 0.4091 - val_acc: 0.8715
# Epoch 83/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.4104 - acc: 0.8663 - val_loss: 0.3714 - val_acc: 0.8750
# Epoch 84/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.3505 - acc: 0.8828 - val_loss: 0.4401 - val_acc: 0.8299
# Epoch 85/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.3205 - acc: 0.9015 - val_loss: 0.5048 - val_acc: 0.8507
# Epoch 86/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.3335 - acc: 0.8915 - val_loss: 0.4135 - val_acc: 0.8576
# Epoch 87/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.4115 - acc: 0.8615 - val_loss: 0.4591 - val_acc: 0.8403
# Epoch 88/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.3411 - acc: 0.8958 - val_loss: 0.3880 - val_acc: 0.8785
# Epoch 89/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.2833 - acc: 0.9093 - val_loss: 0.3754 - val_acc: 0.8924
# Epoch 90/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.2930 - acc: 0.9045 - val_loss: 0.2884 - val_acc: 0.9028
# Epoch 91/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.2853 - acc: 0.9071 - val_loss: 0.2677 - val_acc: 0.9062
# Epoch 92/100
# 2304/2304 [==============================] - 4s 2ms/step - loss: 0.2040 - acc: 0.9358 - val_loss: 0.3236 - val_acc: 0.8993
# Epoch 93/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.4635 - acc: 0.8676 - val_loss: 0.5817 - val_acc: 0.7917
# Epoch 94/100
# 2304/2304 [==============================] - 4s 2ms/step - loss: 0.6501 - acc: 0.8168 - val_loss: 0.4174 - val_acc: 0.8542
# Epoch 95/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.3404 - acc: 0.8980 - val_loss: 0.2955 - val_acc: 0.8958
# Epoch 96/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.2181 - acc: 0.9288 - val_loss: 0.2216 - val_acc: 0.9271
# Epoch 97/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.1806 - acc: 0.9444 - val_loss: 0.1754 - val_acc: 0.9410
# Epoch 98/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.2431 - acc: 0.9258 - val_loss: 0.2153 - val_acc: 0.9201
# Epoch 99/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.2870 - acc: 0.9036 - val_loss: 0.3156 - val_acc: 0.8819
# Epoch 100/100
# 2304/2304 [==============================] - 3s 1ms/step - loss: 0.2293 - acc: 0.9301 - val_loss: 0.2094 - val_acc: 0.9236

# %%
### loss plots using LSTM model
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
### accuracy plots using LSTM model
plt.clf()                                                

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'ro', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-f5941c7aafbf> in <module>
#       2 plt.clf()
#       3
# ----> 4 acc = history.history['accuracy']
#       5 val_acc = history.history['val_accuracy']
#       6
#
# KeyError: 'accuracy'

# %% [markdown]
# *  **(evaluate function): Returns the loss value & metrics values for the model in test mode.**

# %%
### evaluate using model A
model_A.evaluate(np.expand_dims(ravdess_speech_data_array[training_samples + validation_samples:], -1), labels_categorical[training_samples + validation_samples:])
# Out:
# 288/288 [==============================] - 0s 338us/step
# [0.21110256181822884, 0.9375]

# %% [markdown]
# * **  Save the weights of the model as a HDF5 file **

# %%
model_A.save_weights("Model_LSTM.h5")
